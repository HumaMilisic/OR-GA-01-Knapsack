# %%
dir = pwd()
cd("$dir\\input")

type parr
    n::Int
    m::Int
    rjesenje::Int
end

# %%
function openNth(br,sadrzaj)
    filein = open(sadrzaj[br])
    puni=""
    for line in eachline(filein)
        puni = puni * line
    end
    puni = strip(puni)
    #println(puni)
    close(filein)
    return puni
end


function parsiraj!(puni,c,A,b,par::parr)
    brojevi_str = split(puni,r" |\r|\n",keep=false)
    par.n = parse(Int,brojevi_str[1])
    par.m = parse(Int,brojevi_str[2])
    par.rjesenje = parse(Int,brojevi_str[3])
    
    cA = brojevi_str[4:(3+par.n)]
    tempA = brojevi_str[4+par.n:(3+par.n+par.n*par.m)]
    bA = brojevi_str[4+par.n+par.n*par.m:(3+par.n+par.n*par.m+par.m)]
    
    for i in bA
        ii = parse(Float64,i)
        push!(b,ii)
    end
    for i in cA
        ii = parse(Float64,i)
        push!(c,ii)
    end
    
    for poc in 1:par.m:(par.m*par.n)
        #println(poc)
        tt = []
        for i in 0:(par.m-1)
            #print(tempA[poc+i]*" ")
            push!(tt,parse(Float64,tempA[poc+i]))
        end

        push!(A,map(Float64,tt))
    end
end
# Out:
# parsiraj! (generic function with 1 method)

# %%
type Individua
    Duzina
    Hromozom
    Fitnes::Float64
end
function Individua(Duzina::Int)
    Hromozom = BitArray(Duzina)
    rand!(Hromozom)
    return Individua(Duzina,Hromozom,0.0)
end
function Individua(Hromozom::BitArray)
    Duzina = length(Hromozom)
    return Individua(Duzina,Hromozom,0.0)
end
function Mutiraj!(a::Individua)
    poz = rand(1:a.Duzina)
    a.Hromozom[poz] = !a.Hromozom[poz]
    return a
end
function Ukrstanje(a::Individua,b::Individua,p::Float64)
    tacka = rand(1:(a.Duzina-1))
    #println(tacka)
    t1 = Individua([a.Hromozom[1:tacka];b.Hromozom[(tacka+1):end]])
    t2 = Individua([b.Hromozom[1:tacka];a.Hromozom[(tacka+1):end]])
    if(p>rand())
        return t1
    end
    return t2
end
function UInt(niz)
    rez=Array(Float64,0)
    for a in niz
        push!(rez,Float64(a))
    end
    return rez;
end
# Out:
# UInt (generic function with 1 method)

# %%
function Evauliraj!(a::Individua,A,c,b,n,m)
    #a.Fitnes = rand()
    tt=UInt(a.Hromozom)
    fitnes = tt'*c
    kazna = fitnes
    for i in 1:m
        sum =0.0;
        for j in 1:n
            sum+=(A[j][i]*tt[j])
        end
        if sum>b[i]
            #print(!)
            fitnes-=kazna
        end
        #return fitnes
    end
    #println(fitnes)
    a.Fitnes = fitnes[1]
end
# Out:
# Evauliraj! (generic function with 1 method)

# %%
type Populacija
    DuzinaHromozoma::Int
    MaxGeneracija::Int
    VelicinaPopulacije::Int
    BrElite::Int
    BrMutacija::Int
    Iteracija::Int
    Populacija
end
function Populacija(Duzina::Int64)
    MaxGeneracija = 1000*Duzina # 100 * brojvarijabli
    VelicinaPopulacije = 30#20
    BrElite = 1;
    BrMutacija = 25;
    Iteracija = 0;
    populacija = [];
    for a in 1:VelicinaPopulacije
        push!(populacija,Individua(Duzina))
    end
    return Populacija(Duzina,MaxGeneracija,VelicinaPopulacije,BrElite,BrMutacija,Iteracija,populacija)
end
function EvalPop!(pop::Populacija,m,n,A,b,c)
    for a in pop.Populacija
        Evauliraj!(a,A,c,b,n,m)
    end
    sort!(pop.Populacija, by=x->(x.Fitnes), rev=true)
end
function Turnir(pop::Populacija,m::Int64,p::Float64)
    rez = [];
    for a in 1:m
        temp = [];
        t = rand(1:pop.VelicinaPopulacije)
        push!(temp,pop.Populacija[t])
        t = rand(1:pop.VelicinaPopulacije)
        push!(temp,pop.Populacija[t])
        sort!(temp,by=x->(x.Fitnes))
        if(p<rand())
            push!(rez,temp[1])
        else
            push!(rez,temp[2])
        end
    end
    return rez
end
# Out:
# Turnir (generic function with 1 method)

# %%
function DajElite(pop::Populacija)
    br = pop.BrElite
    return pop.Populacija[1:br]
end
function DajDjecu(pop::Populacija,roditelji)
    rez = []
    brDjece = pop.VelicinaPopulacije - pop.BrElite
    while length(rez)<=brDjece
        r1 = roditelji[rand(1:length(roditelji))]
        r2 = roditelji[rand(1:length(roditelji))]
        d = Ukrstanje(r1,r2,0.6)
        push!(rez,d)
    end
    return rez
end
function Mutacija(pop::Populacija,djeca)
    for i in pop.BrMutacija
        br = rand(1:length(djeca))
        #println(br)
        d = djeca[br]
        t = Mutiraj!(d)
        d = t;
    end
end
function ProsjekFitnesa(pop::Populacija)
    suma = 0;
    for a in pop.Populacija 
        suma+=a.Fitnes 
    end
    suma/=length(pop.Populacija)
    return suma
end
# Out:
# ProsjekFitnesa (generic function with 1 method)

# %%
sadrzaj = readdir()

for file in 1:50
    println("-- $file --")
    puni = openNth(1,sadrzaj)
    c = Array(Float64,0); b= Array(Float64,0)
    A = []
    par = parr(0,0,0)
    parsiraj!(puni,c,A,b,par)
    n = par.n; m= par.m; rjesenje = par.rjesenje
    
 #           b = [5]
  #      A = [2,3,4,5]
   #     c = [3,4,5,6]
    
  #  n = 4
   # m = 1
    
    
    println("n = $(n) broj objekata, dimenzije hromozoma\nm = $(m) broj dimenzija\nrjesenje = $rjesenje\n")
    #println("\nc = $c\nb = $b\nA = $A")
    
    #inicijalna populacija
    pop = Populacija(n)
    
    for pop.Iteracija in 1:pop.MaxGeneracija


        
        EvalPop!(pop::Populacija,m,n,A,b,c)

        prosjek = ProsjekFitnesa(pop)
        naj = pop.Populacija[1].Fitnes
        if(pop.Iteracija==pop.MaxGeneracija)
            println("Prosjek fitnesa $prosjek, najbolji fitnes $naj\n\n")
        end

        #println("- populacija $pop\n")

        elite = DajElite(pop)

        #println("- elite $elite\n")

        roditelji = Turnir(pop,Int(pop.VelicinaPopulacije/2),0.9)

        #println("- roditelji $roditelji\n")

        djeca = DajDjecu(pop,roditelji)

        #println("- djeca $djeca\n")

        Mutacija(pop,djeca)

        #println("- djeca $djeca\n")

        #novagen = 
        append!(djeca,elite)

        #println("- nova gen $djeca\n")
        
        pop.Populacija = djeca

    
        #println(pop.Iteracija)
    end
    
    
    
    #break
end
# Out:
# -- 1 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2758.064516129032, najbolji fitnes 2850.0
#
#
# -- 2 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3477.0967741935483, najbolji fitnes 3490.0
#
#
# -- 3 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3260.3225806451615, najbolji fitnes 3490.0
#
#
# -- 4 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 5 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2506.451612903226, najbolji fitnes 2590.0
#
#
# -- 6 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3391.935483870968, najbolji fitnes 3630.0
#
#
# -- 7 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3586.7741935483873, najbolji fitnes 3590.0
#
#
# -- 8 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2578.3870967741937, najbolji fitnes 2770.0
#
#
# -- 9 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3241.2903225806454, najbolji fitnes 3260.0
#
#
# -- 10 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2791.935483870968, najbolji fitnes 2885.0
#
#
# -- 11 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3115.483870967742, najbolji fitnes 3120.0
#
#
# -- 12 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3027.7419354838707, najbolji fitnes 3240.0
#
#
# -- 13 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2974.8387096774195, najbolji fitnes 2980.0
#
#
# -- 14 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3583.7096774193546, najbolji fitnes 3835.0
#
#
# -- 15 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2745.1612903225805, najbolji fitnes 3055.0
#
#
# -- 16 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3338.7096774193546, najbolji fitnes 3450.0
#
#
# -- 17 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2681.6129032258063, najbolji fitnes 2870.0
#
#
# -- 18 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3391.2903225806454, najbolji fitnes 3630.0
#
#
# -- 19 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3022.0967741935483, najbolji fitnes 3035.0
#
#
# -- 20 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3312.0967741935483, najbolji fitnes 3325.0
#
#
# -- 21 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2552.0967741935483, najbolji fitnes 2565.0
#
#
# -- 22 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3106.6129032258063, najbolji fitnes 3325.0
#
#
# -- 23 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3320.483870967742, najbolji fitnes 3325.0
#
#
# -- 24 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3116.1290322580644, najbolji fitnes 3220.0
#
#
# -- 25 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3072.0967741935483, najbolji fitnes 3085.0
#
#
# -- 26 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3711.2903225806454, najbolji fitnes 3730.0
#
#
# -- 27 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2332.0967741935483, najbolji fitnes 2345.0
#
#
# -- 28 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3390.6451612903224, najbolji fitnes 3630.0
#
#
# -- 29 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3443.7096774193546, najbolji fitnes 3695.0
#
#
# -- 30 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 31 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3247.0967741935483, najbolji fitnes 3260.0
#
#
# -- 32 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3449.6774193548385, najbolji fitnes 3835.0
#
#
# -- 33 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2967.0967741935483, najbolji fitnes 2980.0
#
#
# -- 34 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3471.2903225806454, najbolji fitnes 3490.0
#
#
# -- 35 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3377.4193548387098, najbolji fitnes 3490.0
#
#
# -- 36 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3274.8387096774195, najbolji fitnes 3280.0
#
#
# -- 37 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2961.2903225806454, najbolji fitnes 2980.0
#
#
# -- 38 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2584.6774193548385, najbolji fitnes 2770.0
#
#
# -- 39 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 40 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3122.4193548387098, najbolji fitnes 3595.0
#
#
# -- 41 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3583.7096774193546, najbolji fitnes 3835.0
#
#
# -- 42 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3389.1935483870966, najbolji fitnes 3630.0
#
#
# -- 43 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3166.2903225806454, najbolji fitnes 3185.0
#
#
# -- 44 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3078.3870967741937, najbolji fitnes 3085.0
#
#
# -- 45 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3484.8387096774195, najbolji fitnes 3490.0
#
#
# -- 46 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2972.5806451612902, najbolji fitnes 3200.0
#
#
# -- 47 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3130.6451612903224, najbolji fitnes 3235.0
#
#
# -- 48 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3485.483870967742, najbolji fitnes 3730.0
#
#
# -- 49 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3726.7741935483873, najbolji fitnes 3730.0
#
#
# -- 50 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2976.7741935483873, najbolji fitnes 2980.0

# %%
suma = 30
suma/=2
# Out:
# 15.0
