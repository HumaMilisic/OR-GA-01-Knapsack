# %%
dir = pwd()
cd("$dir\\input")

type parr
    n::Int
    m::Int
    rjesenje::Int
end

# %%
function openNth(br,sadrzaj)
    filein = open(sadrzaj[br])
    puni=""
    for line in eachline(filein)
        puni = puni * line
    end
    puni = strip(puni)
    #println(puni)
    close(filein)
    return puni
end


function parsiraj!(puni,c,A,b,par::parr)
    brojevi_str = split(puni,r" |\r|\n",keep=false)
    par.n = parse(Int,brojevi_str[1])
    par.m = parse(Int,brojevi_str[2])
    par.rjesenje = parse(Int,brojevi_str[3])
    
    cA = brojevi_str[4:(3+par.n)]
    tempA = brojevi_str[4+par.n:(3+par.n+par.n*par.m)]
    bA = brojevi_str[4+par.n+par.n*par.m:(3+par.n+par.n*par.m+par.m)]
    
    for i in bA
        ii = parse(Float64,i)
        push!(b,ii)
    end
    for i in cA
        ii = parse(Float64,i)
        push!(c,ii)
    end
    
    for poc in 1:par.m:(par.m*par.n)
        #println(poc)
        tt = []
        for i in 0:(par.m-1)
            #print(tempA[poc+i]*" ")
            push!(tt,parse(Float64,tempA[poc+i]))
        end

        push!(A,map(Float64,tt))
    end
end
# Out:
# parsiraj! (generic function with 1 method)

# %%
type Individua
    Duzina
    Hromozom
    Fitnes::Float64
end
function Individua(Duzina::Int)
    Hromozom = BitArray(Duzina)
    rand!(Hromozom)
    return Individua(Duzina,Hromozom,0.0)
end
function Individua(Hromozom::BitArray)
    Duzina = length(Hromozom)
    return Individua(Duzina,Hromozom,0.0)
end
function Mutiraj!(a::Individua)
    poz = rand(1:a.Duzina)
    a.Hromozom[poz] = !a.Hromozom[poz]
    return a
end
function Ukrstanje(a::Individua,b::Individua,p::Float64)
    tacka1 = rand(1:(a.Duzina-1))
    tacka2 = rand(1:(a.Duzina-1))
    if(tacka2<tacka1)
        temp = tacka2
        tacka2 = tacka1
        tacka1 = temp
    end
    #println(tacka)
    t1 = Individua([a.Hromozom[1:tacka1];b.Hromozom[(tacka1+1):tacka2];a.Hromozom[(tacka2+1):end]])
    t2 = Individua([b.Hromozom[1:tacka1];a.Hromozom[(tacka1+1):tacka2];b.Hromozom[(tacka2+1):end]])
    if(p>rand())
        return t1
    end
    return t2
end

function UkrstanjeN(a::Individua,b::Individua,p::Float64,n::Int)
    tacke = Array(Int,0)
    niz = 2:(a.Duzina-1)
    #println(niz)
    for s in 1:n
        t = rand(niz)
        push!(tacke,t)
    end
    sort!(tacke)

    kraj = length(tacke)
    h1 = [b.Hromozom[1:tacke[1]]]
    h2 = [a.Hromozom[1:tacke[1]]]
    #println(h1)
    for i in 1:2:(kraj-1)
        
        if((i+1)>kraj||(i+2)>kraj)
            break
        end
        #println("tacke[$i] = $(tacke[i]), tacke[$i+1] = $(tacke[i+1]), tacke[$i+2] = $(tacke[i+2])")
        #a.Hromozom[tacka[i]:tacka[i+1]];b.Hromozom[(tacka[i+1]+1):tacka[i+2]]
        temp = h1
        h1 = [temp;a.Hromozom[(tacke[i]+1):tacke[i+1]];b.Hromozom[(tacke[i+1]+1):tacke[i+2]]]
        h2 = [temp;b.Hromozom[(tacke[i]+1):tacke[i+1]];a.Hromozom[(tacke[i+1]+1):tacke[i+2]]]
    end
    
    h1 = [h1;b.Hromozom[(tacke[kraj]+1):end]]
    h2 = [h2;a.Hromozom[(tacke[kraj]+1):end]]
    
    t1 = Individua(h1)
    t2 = Individua(h2)    
    
    if(p>rand())
        return t1
    end
    return t2
end

function UInt(niz)
    rez=Array(Float64,0)
    for a in niz
        push!(rez,Float64(a))
    end
    return rez;
end
# Out:
# UInt (generic function with 1 method)

# %%
function Evauliraj!(a::Individua,A,c,b,n,m)
    #a.Fitnes = rand()
    tt=UInt(a.Hromozom)
    fitnes = tt'*c
    kazna = fitnes
    for i in 1:m
        sum =0.0;
        for j in 1:n
            sum+=(A[j][i]*tt[j])
        end
        if sum>b[i]
            #print(!)
            fitnes-=kazna
        end
        #return fitnes
    end
    #println(fitnes)
    a.Fitnes = fitnes[1]
end
# Out:
# Evauliraj! (generic function with 1 method)

# %%
type Populacija
    DuzinaHromozoma::Int
    MaxGeneracija::Int
    VelicinaPopulacije::Int
    BrElite::Int
    BrMutacija::Int
    Iteracija::Int
    Populacija
end
function Populacija(Duzina::Int64)
    MaxGeneracija = 100*Duzina # 100 * brojvarijabli
    VelicinaPopulacije = 30
    BrElite = 1;
    BrMutacija = 25;
    Iteracija = 0;
    populacija = [];
    for a in 1:VelicinaPopulacije
        push!(populacija,Individua(Duzina))
    end
    return Populacija(Duzina,MaxGeneracija,VelicinaPopulacije,BrElite,BrMutacija,Iteracija,populacija)
end
function EvalPop!(pop::Populacija,m,n,A,b,c)
    for a in pop.Populacija
        Evauliraj!(a,A,c,b,n,m)
    end
    sort!(pop.Populacija, by=x->(x.Fitnes), rev=true)
end
function Turnir(pop::Populacija,m::Int64,p::Float64)
    rez = [];
    for a in 1:m
        temp = [];
        t = rand(1:pop.VelicinaPopulacije)
        push!(temp,pop.Populacija[t])
        t = rand(1:pop.VelicinaPopulacije)
        push!(temp,pop.Populacija[t])
        sort!(temp,by=x->(x.Fitnes))
        if(p<rand())
            push!(rez,temp[1])
        else
            push!(rez,temp[2])
        end
    end
    return rez
end
# Out:
# Turnir (generic function with 1 method)

# %%
function DajElite(pop::Populacija)
    br = pop.BrElite
    return pop.Populacija[1:br]
end
function DajDjecu(pop::Populacija,roditelji)
    rez = []
    brDjece = pop.VelicinaPopulacije - pop.BrElite
    while length(rez)<=brDjece
        r1 = roditelji[rand(1:length(roditelji))]
        r2 = roditelji[rand(1:length(roditelji))]
        #d = UkrstanjeN(r1,r2,0.6,5)
        d = Ukrstanje(r1,r2,0.6)
        push!(rez,d)
    end
    return rez
end
function Mutacija(pop::Populacija,djeca)
    for i in pop.BrMutacija
        br = rand(1:length(djeca))
        #println(br)
        d = djeca[br]
        t = Mutiraj!(d)
        d = t;
    end
end
function ProsjekFitnesa(pop::Populacija)
    suma = 0;
    for a in pop.Populacija 
        suma+=a.Fitnes 
    end
    suma/=length(pop.Populacija)
    return suma
end
# Out:
# ProsjekFitnesa (generic function with 1 method)

# %%
sadrzaj = readdir()

max = 0;
maxhistorija = []
for file in 1:500
    println("-- $file --")
    puni = openNth(1,sadrzaj)
    c = Array(Float64,0); b= Array(Float64,0)
    A = []
    par = parr(0,0,0)
    parsiraj!(puni,c,A,b,par)
    n = par.n; m= par.m; rjesenje = par.rjesenje
    
 #           b = [5]
  #      A = [2,3,4,5]
   #     c = [3,4,5,6]
    
  #  n = 4
   # m = 1
    
    
    println("n = $(n) broj objekata, dimenzije hromozoma\nm = $(m) broj dimenzija\nrjesenje = $rjesenje\n")
    #println("\nc = $c\nb = $b\nA = $A")
    
    #inicijalna populacija
    pop = Populacija(n)
    
    for pop.Iteracija in 1:pop.MaxGeneracija


        
        EvalPop!(pop::Populacija,m,n,A,b,c)

        prosjek = ProsjekFitnesa(pop)
        naj = pop.Populacija[1].Fitnes
        
        if(max<naj)
            max = naj
        end
        
        if(pop.Iteracija==pop.MaxGeneracija)
            println("Prosjek fitnesa $prosjek, najbolji fitnes $naj\n\n")
        end

        #println("- populacija $pop\n")

        elite = DajElite(pop)

        #println("- elite $elite\n")

        roditelji = Turnir(pop,Int(pop.VelicinaPopulacije/2),0.9)

        #println("- roditelji $roditelji\n")

        djeca = DajDjecu(pop,roditelji)

        #println("- djeca $djeca\n")

        Mutacija(pop,djeca)

        #println("- djeca $djeca\n")

        #novagen = 
        append!(djeca,elite)

        #println("- nova gen $djeca\n")
        
        pop.Populacija = djeca

    
        #println(pop.Iteracija)
    end
    
    
    
    #break
end

println("Max $max")
# Out:
# -- 1 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2937.0967741935483, najbolji fitnes 3035.0
#
#
# -- 2 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2241.7741935483873, najbolji fitnes 2585.0
#
#
# -- 3 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2830.967741935484, najbolji fitnes 3040.0
#
#
# -- 4 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3082.2580645161293, najbolji fitnes 3185.0
#
#
# -- 5 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3577.0967741935483, najbolji fitnes 3590.0
#
#
# -- 6 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2481.935483870968, najbolji fitnes 2755.0
#
#
# -- 7 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3793.064516129032, najbolji fitnes 3835.0
#
#
# -- 8 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2811.2903225806454, najbolji fitnes 2905.0
#
#
# -- 9 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3009.3548387096776, najbolji fitnes 3220.0
#
#
# -- 10 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3115.483870967742, najbolji fitnes 3120.0
#
#
# -- 11 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3471.2903225806454, najbolji fitnes 3490.0
#
#
# -- 12 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 1821.2903225806451, najbolji fitnes 1950.0
#
#
# -- 13 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3443.7096774193546, najbolji fitnes 3695.0
#
#
# -- 14 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2958.548387096774, najbolji fitnes 3185.0
#
#
# -- 15 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3055.483870967742, najbolji fitnes 3280.0
#
#
# -- 16 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2137.0967741935483, najbolji fitnes 2150.0
#
#
# -- 17 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3283.064516129032, najbolji fitnes 3325.0
#
#
# -- 18 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2831.6129032258063, najbolji fitnes 3030.0
#
#
# -- 19 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2658.064516129032, najbolji fitnes 2700.0
#
#
# -- 20 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3280.6451612903224, najbolji fitnes 3390.0
#
#
# -- 21 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2727.0967741935483, najbolji fitnes 3035.0
#
#
# -- 22 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3218.064516129032, najbolji fitnes 3260.0
#
#
# -- 23 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3486.451612903226, najbolji fitnes 3730.0
#
#
# -- 24 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2840.6451612903224, najbolji fitnes 3040.0
#
#
# -- 25 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2540.3225806451615, najbolji fitnes 2625.0
#
#
# -- 26 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3038.064516129032, najbolji fitnes 3080.0
#
#
# -- 27 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2541.7741935483873, najbolji fitnes 2545.0
#
#
# -- 28 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3181.2903225806454, najbolji fitnes 3200.0
#
#
# -- 29 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3154.8387096774195, najbolji fitnes 3260.0
#
#
# -- 30 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2951.6129032258063, najbolji fitnes 3050.0
#
#
# -- 31 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3720.3225806451615, najbolji fitnes 3730.0
#
#
# -- 32 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2930.3225806451615, najbolji fitnes 2940.0
#
#
# -- 33 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2774.032258064516, najbolji fitnes 2795.0
#
#
# -- 34 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2682.0967741935483, najbolji fitnes 2695.0
#
#
# -- 35 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3318.3870967741937, najbolji fitnes 3325.0
#
#
# -- 36 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3577.0967741935483, najbolji fitnes 3590.0
#
#
# -- 37 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2742.0967741935483, najbolji fitnes 2755.0
#
#
# -- 38 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2989.032258064516, najbolji fitnes 3325.0
#
#
# -- 39 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2883.8709677419356, najbolji fitnes 2980.0
#
#
# -- 40 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2685.1612903225805, najbolji fitnes 2980.0
#
#
# -- 41 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3019.3548387096776, najbolji fitnes 3120.0
#
#
# -- 42 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3482.2580645161293, najbolji fitnes 3730.0
#
#
# -- 43 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3023.3870967741937, najbolji fitnes 3235.0
#
#
# -- 44 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2378.3870967741937, najbolji fitnes 2550.0
#
#
# -- 45 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2878.3870967741937, najbolji fitnes 2885.0
#
#
# -- 46 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2661.2903225806454, najbolji fitnes 2750.0
#
#
# -- 47 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 48 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2252.0967741935483, najbolji fitnes 2265.0
#
#
# -- 49 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3486.451612903226, najbolji fitnes 3730.0
#
#
# -- 50 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3283.064516129032, najbolji fitnes 3325.0
#
#
# -- 51 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3452.7419354838707, najbolji fitnes 3695.0
#
#
# -- 52 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2501.6129032258063, najbolji fitnes 2585.0
#
#
# -- 53 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3008.3870967741937, najbolji fitnes 3220.0
#
#
# -- 54 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3720.3225806451615, najbolji fitnes 3730.0
#
#
# -- 55 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3486.7741935483873, najbolji fitnes 3490.0
#
#
# -- 56 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2559.6774193548385, najbolji fitnes 2645.0
#
#
# -- 57 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3023.3870967741937, najbolji fitnes 3235.0
#
#
# -- 58 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2685.8064516129034, najbolji fitnes 2980.0
#
#
# -- 59 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3078.3870967741937, najbolji fitnes 3085.0
#
#
# -- 60 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3377.4193548387098, najbolji fitnes 3490.0
#
#
# -- 61 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3116.1290322580644, najbolji fitnes 3220.0
#
#
# -- 62 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3583.7096774193546, najbolji fitnes 3835.0
#
#
# -- 63 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3275.483870967742, najbolji fitnes 3280.0
#
#
# -- 64 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3217.7419354838707, najbolji fitnes 3325.0
#
#
# -- 65 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3485.483870967742, najbolji fitnes 3730.0
#
#
# -- 66 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3247.0967741935483, najbolji fitnes 3260.0
#
#
# -- 67 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2552.0967741935483, najbolji fitnes 2565.0
#
#
# -- 68 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3036.1290322580644, najbolji fitnes 3040.0
#
#
# -- 69 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3688.064516129032, najbolji fitnes 3730.0
#
#
# -- 70 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3793.064516129032, najbolji fitnes 3835.0
#
#
# -- 71 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3484.8387096774195, najbolji fitnes 3490.0
#
#
# -- 72 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2956.1290322580644, najbolji fitnes 2960.0
#
#
# -- 73 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3014.032258064516, najbolji fitnes 3035.0
#
#
# -- 74 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3247.0967741935483, najbolji fitnes 3260.0
#
#
# -- 75 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2264.516129032258, najbolji fitnes 2340.0
#
#
# -- 76 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3446.935483870968, najbolji fitnes 3695.0
#
#
# -- 77 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3586.7741935483873, najbolji fitnes 3590.0
#
#
# -- 78 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3369.032258064516, najbolji fitnes 3390.0
#
#
# -- 79 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3682.0967741935483, najbolji fitnes 3695.0
#
#
# -- 80 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2796.7741935483873, najbolji fitnes 2800.0
#
#
# -- 81 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3485.483870967742, najbolji fitnes 3730.0
#
#
# -- 82 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2970.3225806451615, najbolji fitnes 2980.0
#
#
# -- 83 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3822.0967741935483, najbolji fitnes 3835.0
#
#
# -- 84 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2932.2580645161293, najbolji fitnes 3030.0
#
#
# -- 85 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2656.451612903226, najbolji fitnes 2745.0
#
#
# -- 86 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2526.7741935483873, najbolji fitnes 2530.0
#
#
# -- 87 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3115.483870967742, najbolji fitnes 3120.0
#
#
# -- 88 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 89 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3117.0967741935483, najbolji fitnes 3590.0
#
#
# -- 90 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3320.483870967742, najbolji fitnes 3325.0
#
#
# -- 91 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2206.451612903226, najbolji fitnes 2280.0
#
#
# -- 92 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2538.3870967741937, najbolji fitnes 2545.0
#
#
# -- 93 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2840.967741935484, najbolji fitnes 3040.0
#
#
# -- 94 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3828.3870967741937, najbolji fitnes 3835.0
#
#
# -- 95 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3688.3870967741937, najbolji fitnes 3695.0
#
#
# -- 96 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 97 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3118.064516129032, najbolji fitnes 3590.0
#
#
# -- 98 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3469.032258064516, najbolji fitnes 3490.0
#
#
# -- 99 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3234.8387096774195, najbolji fitnes 3240.0
#
#
# -- 100 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3828.3870967741937, najbolji fitnes 3835.0
#
#
# -- 101 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3217.7419354838707, najbolji fitnes 3325.0
#
#
# -- 102 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2593.548387096774, najbolji fitnes 2680.0
#
#
# -- 103 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2655.3225806451615, najbolji fitnes 2665.0
#
#
# -- 104 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3548.064516129032, najbolji fitnes 3590.0
#
#
# -- 105 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2626.7741935483873, najbolji fitnes 2630.0
#
#
# -- 106 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3585.3225806451615, najbolji fitnes 3595.0
#
#
# -- 107 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3254.8387096774195, najbolji fitnes 3260.0
#
#
# -- 108 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3105.3225806451615, najbolji fitnes 3325.0
#
#
# -- 109 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3187.0967741935483, najbolji fitnes 3200.0
#
#
# -- 110 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3180.483870967742, najbolji fitnes 3185.0
#
#
# -- 111 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3154.8387096774195, najbolji fitnes 3260.0
#
#
# -- 112 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3146.451612903226, najbolji fitnes 3490.0
#
#
# -- 113 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2626.7741935483873, najbolji fitnes 2630.0
#
#
# -- 114 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3055.483870967742, najbolji fitnes 3280.0
#
#
# -- 115 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2579.8387096774195, najbolji fitnes 2585.0
#
#
# -- 116 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2511.7741935483873, najbolji fitnes 2895.0
#
#
# -- 117 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 118 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3154.8387096774195, najbolji fitnes 3260.0
#
#
# -- 119 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3106.451612903226, najbolji fitnes 3210.0
#
#
# -- 120 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2742.0967741935483, najbolji fitnes 2755.0
#
#
# -- 121 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3553.064516129032, najbolji fitnes 3595.0
#
#
# -- 122 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2593.548387096774, najbolji fitnes 2680.0
#
#
# -- 123 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2379.3548387096776, najbolji fitnes 2650.0
#
#
# -- 124 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3689.8387096774195, najbolji fitnes 3695.0
#
#
# -- 125 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3477.0967741935483, najbolji fitnes 3490.0
#
#
# -- 126 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2378.548387096774, najbolji fitnes 2565.0
#
#
# -- 127 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3457.4193548387098, najbolji fitnes 3835.0
#
#
# -- 128 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3448.064516129032, najbolji fitnes 3490.0
#
#
# -- 129 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3201.2903225806454, najbolji fitnes 3220.0
#
#
# -- 130 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 131 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2500.0, najbolji fitnes 2680.0
#
#
# -- 132 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2791.935483870968, najbolji fitnes 2885.0
#
#
# -- 133 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2956.7741935483873, najbolji fitnes 2960.0
#
#
# -- 134 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 135 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3260.967741935484, najbolji fitnes 3490.0
#
#
# -- 136 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2366.451612903226, najbolji fitnes 2630.0
#
#
# -- 137 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2467.7419354838707, najbolji fitnes 2550.0
#
#
# -- 138 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3584.3548387096776, najbolji fitnes 3835.0
#
#
# -- 139 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3130.6451612903224, najbolji fitnes 3235.0
#
#
# -- 140 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2758.064516129032, najbolji fitnes 3060.0
#
#
# -- 141 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2776.2903225806454, najbolji fitnes 2795.0
#
#
# -- 142 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3588.064516129032, najbolji fitnes 3630.0
#
#
# -- 143 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3082.2580645161293, najbolji fitnes 3185.0
#
#
# -- 144 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3115.483870967742, najbolji fitnes 3120.0
#
#
# -- 145 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2512.0967741935483, najbolji fitnes 2525.0
#
#
# -- 146 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3027.0967741935483, najbolji fitnes 3040.0
#
#
# -- 147 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2758.3870967741937, najbolji fitnes 2765.0
#
#
# -- 148 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3822.0967741935483, najbolji fitnes 3835.0
#
#
# -- 149 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2877.0967741935483, najbolji fitnes 2890.0
#
#
# -- 150 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2603.8709677419356, najbolji fitnes 2890.0
#
#
# -- 151 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3255.1612903225805, najbolji fitnes 3490.0
#
#
# -- 152 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3345.483870967742, najbolji fitnes 3590.0
#
#
# -- 153 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 154 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3617.0967741935483, najbolji fitnes 3630.0
#
#
# -- 155 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3075.3225806451615, najbolji fitnes 3085.0
#
#
# -- 156 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2533.8709677419356, najbolji fitnes 3035.0
#
#
# -- 157 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2862.5806451612902, najbolji fitnes 3185.0
#
#
# -- 158 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2956.1290322580644, najbolji fitnes 3280.0
#
#
# -- 159 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2862.5806451612902, najbolji fitnes 3185.0
#
#
# -- 160 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3005.1612903225805, najbolji fitnes 3220.0
#
#
# -- 161 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3484.8387096774195, najbolji fitnes 3490.0
#
#
# -- 162 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2897.7419354838707, najbolji fitnes 3120.0
#
#
# -- 163 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3065.483870967742, najbolji fitnes 3280.0
#
#
# -- 164 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3585.3225806451615, najbolji fitnes 3595.0
#
#
# -- 165 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3512.9032258064517, najbolji fitnes 3630.0
#
#
# -- 166 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3331.451612903226, najbolji fitnes 3835.0
#
#
# -- 167 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3267.0967741935483, najbolji fitnes 3280.0
#
#
# -- 168 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3377.4193548387098, najbolji fitnes 3490.0
#
#
# -- 169 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2932.2580645161293, najbolji fitnes 3030.0
#
#
# -- 170 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2830.967741935484, najbolji fitnes 3040.0
#
#
# -- 171 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3822.0967741935483, najbolji fitnes 3835.0
#
#
# -- 172 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3482.2580645161293, najbolji fitnes 3730.0
#
#
# -- 173 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3075.483870967742, najbolji fitnes 3080.0
#
#
# -- 174 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2969.8387096774195, najbolji fitnes 3185.0
#
#
# -- 175 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2787.0967741935483, najbolji fitnes 2800.0
#
#
# -- 176 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3110.3225806451615, najbolji fitnes 3120.0
#
#
# -- 177 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3384.8387096774195, najbolji fitnes 3390.0
#
#
# -- 178 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3682.0967741935483, najbolji fitnes 3695.0
#
#
# -- 179 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3482.2580645161293, najbolji fitnes 3730.0
#
#
# -- 180 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2997.4193548387098, najbolji fitnes 3325.0
#
#
# -- 181 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3611.2903225806454, najbolji fitnes 3630.0
#
#
# -- 182 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3620.3225806451615, najbolji fitnes 3630.0
#
#
# -- 183 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2975.483870967742, najbolji fitnes 2980.0
#
#
# -- 184 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3674.032258064516, najbolji fitnes 3695.0
#
#
# -- 185 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 186 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2467.0967741935483, najbolji fitnes 2480.0
#
#
# -- 187 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3476.451612903226, najbolji fitnes 3730.0
#
#
# -- 188 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 189 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2850.3225806451615, najbolji fitnes 3050.0
#
#
# -- 190 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 191 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3377.4193548387098, najbolji fitnes 3490.0
#
#
# -- 192 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2574.1935483870966, najbolji fitnes 2660.0
#
#
# -- 193 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3072.0967741935483, najbolji fitnes 3085.0
#
#
# -- 194 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2370.967741935484, najbolji fitnes 2450.0
#
#
# -- 195 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3154.8387096774195, najbolji fitnes 3260.0
#
#
# -- 196 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3318.3870967741937, najbolji fitnes 3325.0
#
#
# -- 197 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2789.516129032258, najbolji fitnes 2985.0
#
#
# -- 198 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3323.2258064516127, najbolji fitnes 3695.0
#
#
# -- 199 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2874.032258064516, najbolji fitnes 2895.0
#
#
# -- 200 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3318.3870967741937, najbolji fitnes 3325.0
#
#
# -- 201 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2142.0967741935483, najbolji fitnes 2155.0
#
#
# -- 202 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3452.7419354838707, najbolji fitnes 3695.0
#
#
# -- 203 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2071.6129032258063, najbolji fitnes 2340.0
#
#
# -- 204 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3228.3870967741937, najbolji fitnes 3590.0
#
#
# -- 205 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3814.032258064516, najbolji fitnes 3835.0
#
#
# -- 206 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2264.516129032258, najbolji fitnes 2340.0
#
#
# -- 207 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2680.3225806451615, najbolji fitnes 2870.0
#
#
# -- 208 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3145.8064516129034, najbolji fitnes 3490.0
#
#
# -- 209 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3620.3225806451615, najbolji fitnes 3630.0
#
#
# -- 210 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3033.8709677419356, najbolji fitnes 3135.0
#
#
# -- 211 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3575.8064516129034, najbolji fitnes 3695.0
#
#
# -- 212 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2675.8064516129034, najbolji fitnes 2765.0
#
#
# -- 213 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3485.483870967742, najbolji fitnes 3730.0
#
#
# -- 214 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 215 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3482.7419354838707, najbolji fitnes 3730.0
#
#
# -- 216 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3075.3225806451615, najbolji fitnes 3085.0
#
#
# -- 217 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2712.0967741935483, najbolji fitnes 2725.0
#
#
# -- 218 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3217.7419354838707, najbolji fitnes 3325.0
#
#
# -- 219 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3283.064516129032, najbolji fitnes 3325.0
#
#
# -- 220 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3345.483870967742, najbolji fitnes 3590.0
#
#
# -- 221 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2901.1290322580644, najbolji fitnes 2905.0
#
#
# -- 222 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3019.3548387096776, najbolji fitnes 3120.0
#
#
# -- 223 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3512.9032258064517, najbolji fitnes 3630.0
#
#
# -- 224 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3476.451612903226, najbolji fitnes 3730.0
#
#
# -- 225 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3709.032258064516, najbolji fitnes 3730.0
#
#
# -- 226 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2436.7741935483873, najbolji fitnes 2440.0
#
#
# -- 227 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3023.064516129032, najbolji fitnes 3235.0
#
#
# -- 228 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2365.1612903225805, najbolji fitnes 2630.0
#
#
# -- 229 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 230 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2796.7741935483873, najbolji fitnes 2890.0
#
#
# -- 231 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2162.9032258064517, najbolji fitnes 2235.0
#
#
# -- 232 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3711.2903225806454, najbolji fitnes 3730.0
#
#
# -- 233 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2093.548387096774, najbolji fitnes 2325.0
#
#
# -- 234 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2349.3548387096776, najbolji fitnes 2815.0
#
#
# -- 235 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3711.2903225806454, najbolji fitnes 3730.0
#
#
# -- 236 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2528.3870967741937, najbolji fitnes 2815.0
#
#
# -- 237 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3207.0967741935483, najbolji fitnes 3220.0
#
#
# -- 238 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3391.935483870968, najbolji fitnes 3630.0
#
#
# -- 239 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2555.3225806451615, najbolji fitnes 2565.0
#
#
# -- 240 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 241 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2241.7741935483873, najbolji fitnes 2585.0
#
#
# -- 242 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3118.064516129032, najbolji fitnes 3590.0
#
#
# -- 243 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3362.5806451612902, najbolji fitnes 3730.0
#
#
# -- 244 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 245 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 246 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3471.2903225806454, najbolji fitnes 3490.0
#
#
# -- 247 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2332.5806451612902, najbolji fitnes 2795.0
#
#
# -- 248 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3137.0967741935483, najbolji fitnes 3150.0
#
#
# -- 249 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3267.0967741935483, najbolji fitnes 3280.0
#
#
# -- 250 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3143.064516129032, najbolji fitnes 3185.0
#
#
# -- 251 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2698.548387096774, najbolji fitnes 2895.0
#
#
# -- 252 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2748.3870967741937, najbolji fitnes 2840.0
#
#
# -- 253 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2681.6129032258063, najbolji fitnes 2870.0
#
#
# -- 254 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2748.3870967741937, najbolji fitnes 2840.0
#
#
# -- 255 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2918.064516129032, najbolji fitnes 2960.0
#
#
# -- 256 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3238.064516129032, najbolji fitnes 3280.0
#
#
# -- 257 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3474.1935483870966, najbolji fitnes 3590.0
#
#
# -- 258 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3217.7419354838707, najbolji fitnes 3325.0
#
#
# -- 259 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3320.483870967742, najbolji fitnes 3325.0
#
#
# -- 260 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2380.6451612903224, najbolji fitnes 2460.0
#
#
# -- 261 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3359.8387096774195, najbolji fitnes 3595.0
#
#
# -- 262 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3251.1290322580644, najbolji fitnes 3255.0
#
#
# -- 263 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3028.3870967741937, najbolji fitnes 3035.0
#
#
# -- 264 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2759.1935483870966, najbolji fitnes 2955.0
#
#
# -- 265 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 266 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2780.6451612903224, najbolji fitnes 2980.0
#
#
# -- 267 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2698.548387096774, najbolji fitnes 2895.0
#
#
# -- 268 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3676.2903225806454, najbolji fitnes 3695.0
#
#
# -- 269 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2765.8064516129034, najbolji fitnes 2960.0
#
#
# -- 270 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3181.2903225806454, najbolji fitnes 3200.0
#
#
# -- 271 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 1895.483870967742, najbolji fitnes 2040.0
#
#
# -- 272 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3359.8387096774195, najbolji fitnes 3595.0
#
#
# -- 273 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3019.3548387096776, najbolji fitnes 3120.0
#
#
# -- 274 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3576.2903225806454, najbolji fitnes 3595.0
#
#
# -- 275 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3115.483870967742, najbolji fitnes 3120.0
#
#
# -- 276 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2656.451612903226, najbolji fitnes 2745.0
#
#
# -- 277 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3449.6774193548385, najbolji fitnes 3835.0
#
#
# -- 278 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3048.3870967741937, najbolji fitnes 3150.0
#
#
# -- 279 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2734.8387096774195, najbolji fitnes 3035.0
#
#
# -- 280 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3172.0967741935483, najbolji fitnes 3185.0
#
#
# -- 281 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3816.2903225806454, najbolji fitnes 3835.0
#
#
# -- 282 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2980.6451612903224, najbolji fitnes 3080.0
#
#
# -- 283 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3174.1935483870966, najbolji fitnes 3280.0
#
#
# -- 284 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3392.5806451612902, najbolji fitnes 3630.0
#
#
# -- 285 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3107.0967741935483, najbolji fitnes 3120.0
#
#
# -- 286 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 1750.967741935484, najbolji fitnes 1950.0
#
#
# -- 287 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2447.0967741935483, najbolji fitnes 2460.0
#
#
# -- 288 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2911.6129032258063, najbolji fitnes 3120.0
#
#
# -- 289 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3066.2903225806454, najbolji fitnes 3085.0
#
#
# -- 290 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3711.2903225806454, najbolji fitnes 3730.0
#
#
# -- 291 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2729.032258064516, najbolji fitnes 2750.0
#
#
# -- 292 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 293 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3019.3548387096776, najbolji fitnes 3120.0
#
#
# -- 294 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2911.2903225806454, najbolji fitnes 2930.0
#
#
# -- 295 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3122.4193548387098, najbolji fitnes 3595.0
#
#
# -- 296 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 1646.6129032258063, najbolji fitnes 1935.0
#
#
# -- 297 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2834.032258064516, najbolji fitnes 3035.0
#
#
# -- 298 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2528.3870967741937, najbolji fitnes 2815.0
#
#
# -- 299 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3822.0967741935483, najbolji fitnes 3835.0
#
#
# -- 300 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2700.6451612903224, najbolji fitnes 2890.0
#
#
# -- 301 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3087.4193548387098, najbolji fitnes 3695.0
#
#
# -- 302 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3115.483870967742, najbolji fitnes 3120.0
#
#
# -- 303 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2990.0, najbolji fitnes 3210.0
#
#
# -- 304 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3452.7419354838707, najbolji fitnes 3695.0
#
#
# -- 305 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2776.1290322580644, najbolji fitnes 3080.0
#
#
# -- 306 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 1753.8709677419354, najbolji fitnes 2105.0
#
#
# -- 307 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3125.3225806451615, najbolji fitnes 3135.0
#
#
# -- 308 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3187.0967741935483, najbolji fitnes 3200.0
#
#
# -- 309 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3620.3225806451615, najbolji fitnes 3630.0
#
#
# -- 310 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3392.9032258064517, najbolji fitnes 3630.0
#
#
# -- 311 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2564.516129032258, najbolji fitnes 2650.0
#
#
# -- 312 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 313 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2796.7741935483873, najbolji fitnes 2890.0
#
#
# -- 314 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3037.9032258064517, najbolji fitnes 3255.0
#
#
# -- 315 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2568.064516129032, najbolji fitnes 2610.0
#
#
# -- 316 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2703.064516129032, najbolji fitnes 2745.0
#
#
# -- 317 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3228.3870967741937, najbolji fitnes 3590.0
#
#
# -- 318 --
# ...
#
#
# -- 396 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2511.7741935483873, najbolji fitnes 2895.0
#
#
# -- 397 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3234.8387096774195, najbolji fitnes 3240.0
#
#
# -- 398 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3390.6451612903224, najbolji fitnes 3630.0
#
#
# -- 399 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 400 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3711.2903225806454, najbolji fitnes 3730.0
#
#
# -- 401 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3190.3225806451615, najbolji fitnes 3200.0
#
#
# -- 402 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 403 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3816.2903225806454, najbolji fitnes 3835.0
#
#
# -- 404 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2915.8064516129034, najbolji fitnes 3120.0
#
#
# -- 405 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3323.2258064516127, najbolji fitnes 3695.0
#
#
# -- 406 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3168.3870967741937, najbolji fitnes 3390.0
#
#
# -- 407 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2883.8709677419356, najbolji fitnes 2980.0
#
#
# -- 408 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3267.0967741935483, najbolji fitnes 3280.0
#
#
# -- 409 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3586.7741935483873, najbolji fitnes 3590.0
#
#
# -- 410 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3174.1935483870966, najbolji fitnes 3280.0
#
#
# -- 411 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3392.9032258064517, najbolji fitnes 3630.0
#
#
# -- 412 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2036.774193548387, najbolji fitnes 2040.0
#
#
# -- 413 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2007.0967741935483, najbolji fitnes 2020.0
#
#
# -- 414 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3146.451612903226, najbolji fitnes 3490.0
#
#
# -- 415 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3452.7419354838707, najbolji fitnes 3695.0
#
#
# -- 416 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2874.032258064516, najbolji fitnes 2895.0
#
#
# -- 417 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3825.3225806451615, najbolji fitnes 3835.0
#
#
# -- 418 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2774.8387096774195, najbolji fitnes 2980.0
#
#
# -- 419 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3577.0967741935483, najbolji fitnes 3590.0
#
#
# -- 420 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2996.7741935483873, najbolji fitnes 3325.0
#
#
# -- 421 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3371.2903225806454, najbolji fitnes 3390.0
#
#
# -- 422 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3582.4193548387098, najbolji fitnes 3835.0
#
#
# -- 423 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3486.451612903226, najbolji fitnes 3730.0
#
#
# -- 424 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3216.7741935483873, najbolji fitnes 3220.0
#
#
# -- 425 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3474.1935483870966, najbolji fitnes 3590.0
#
#
# -- 426 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2577.0967741935483, najbolji fitnes 2590.0
#
#
# -- 427 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3146.451612903226, najbolji fitnes 3490.0
#
#
# -- 428 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 1872.5806451612902, najbolji fitnes 2160.0
#
#
# -- 429 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3452.0967741935483, najbolji fitnes 3695.0
#
#
# -- 430 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3247.0967741935483, najbolji fitnes 3260.0
#
#
# -- 431 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3009.3548387096776, najbolji fitnes 3220.0
#
#
# -- 432 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3247.0967741935483, najbolji fitnes 3260.0
#
#
# -- 433 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3577.0967741935483, najbolji fitnes 3590.0
#
#
# -- 434 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3216.7741935483873, najbolji fitnes 3220.0
#
#
# -- 435 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3348.064516129032, najbolji fitnes 3390.0
#
#
# -- 436 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2783.8709677419356, najbolji fitnes 2980.0
#
#
# -- 437 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3016.2903225806454, najbolji fitnes 3035.0
#
#
# -- 438 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2666.2903225806454, najbolji fitnes 2895.0
#
#
# -- 439 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2989.032258064516, najbolji fitnes 3325.0
#
#
# -- 440 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2555.3225806451615, najbolji fitnes 2735.0
#
#
# -- 441 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2734.8387096774195, najbolji fitnes 3035.0
#
#
# -- 442 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2506.451612903226, najbolji fitnes 2590.0
#
#
# -- 443 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3711.2903225806454, najbolji fitnes 3730.0
#
#
# -- 444 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3476.451612903226, najbolji fitnes 3730.0
#
#
# -- 445 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3022.0967741935483, najbolji fitnes 3035.0
#
#
# -- 446 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3283.064516129032, najbolji fitnes 3325.0
#
#
# -- 447 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2873.064516129032, najbolji fitnes 3085.0
#
#
# -- 448 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2767.0967741935483, najbolji fitnes 2780.0
#
#
# -- 449 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2972.5806451612902, najbolji fitnes 3200.0
#
#
# -- 450 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3129.032258064516, najbolji fitnes 3150.0
#
#
# -- 451 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3674.032258064516, najbolji fitnes 3695.0
#
#
# -- 452 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3066.2903225806454, najbolji fitnes 3085.0
#
#
# -- 453 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3089.516129032258, najbolji fitnes 3325.0
#
#
# -- 454 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3240.6451612903224, najbolji fitnes 3595.0
#
#
# -- 455 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3571.2903225806454, najbolji fitnes 3590.0
#
#
# -- 456 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3230.3225806451615, najbolji fitnes 3240.0
#
#
# -- 457 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3224.1935483870966, najbolji fitnes 3450.0
#
#
# -- 458 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2986.451612903226, najbolji fitnes 3200.0
#
#
# -- 459 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3022.0967741935483, najbolji fitnes 3035.0
#
#
# -- 460 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 461 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3469.032258064516, najbolji fitnes 3490.0
#
#
# -- 462 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3709.032258064516, najbolji fitnes 3730.0
#
#
# -- 463 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2661.2903225806454, najbolji fitnes 2750.0
#
#
# -- 464 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2192.9032258064517, najbolji fitnes 2630.0
#
#
# -- 465 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3315.3225806451615, najbolji fitnes 3325.0
#
#
# -- 466 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3582.4193548387098, najbolji fitnes 3835.0
#
#
# -- 467 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3390.6451612903224, najbolji fitnes 3630.0
#
#
# -- 468 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3814.032258064516, najbolji fitnes 3835.0
#
#
# -- 469 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3577.0967741935483, najbolji fitnes 3590.0
#
#
# -- 470 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2938.064516129032, najbolji fitnes 2980.0
#
#
# -- 471 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3105.3225806451615, najbolji fitnes 3325.0
#
#
# -- 472 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3391.2903225806454, najbolji fitnes 3630.0
#
#
# -- 473 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2951.6129032258063, najbolji fitnes 3050.0
#
#
# -- 474 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3047.0967741935483, najbolji fitnes 3060.0
#
#
# -- 475 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3609.6774193548385, najbolji fitnes 3730.0
#
#
# -- 476 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3283.064516129032, najbolji fitnes 3325.0
#
#
# -- 477 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3720.3225806451615, najbolji fitnes 3730.0
#
#
# -- 478 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3377.4193548387098, najbolji fitnes 3490.0
#
#
# -- 479 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3026.7741935483873, najbolji fitnes 3030.0
#
#
# -- 480 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3583.7096774193546, najbolji fitnes 3835.0
#
#
# -- 481 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2911.6129032258063, najbolji fitnes 3120.0
#
#
# -- 482 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2992.0967741935483, najbolji fitnes 3005.0
#
#
# -- 483 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2607.0967741935483, najbolji fitnes 2895.0
#
#
# -- 484 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3312.0967741935483, najbolji fitnes 3325.0
#
#
# -- 485 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2935.483870967742, najbolji fitnes 2940.0
#
#
# -- 486 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2327.0967741935483, najbolji fitnes 2340.0
#
#
# -- 487 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3717.0967741935483, najbolji fitnes 3730.0
#
#
# -- 488 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3617.0967741935483, najbolji fitnes 3630.0
#
#
# -- 489 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2275.3225806451615, najbolji fitnes 2285.0
#
#
# -- 490 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3477.0967741935483, najbolji fitnes 3490.0
#
#
# -- 491 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2037.0967741935483, najbolji fitnes 2105.0
#
#
# -- 492 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3388.7096774193546, najbolji fitnes 3630.0
#
#
# -- 493 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3035.3225806451615, najbolji fitnes 3255.0
#
#
# -- 494 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3234.8387096774195, najbolji fitnes 3240.0
#
#
# -- 495 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2870.3225806451615, najbolji fitnes 3185.0
#
#
# -- 496 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2791.935483870968, najbolji fitnes 2885.0
#
#
# -- 497 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2777.4193548387098, najbolji fitnes 2870.0
#
#
# -- 498 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 3196.7741935483873, najbolji fitnes 3200.0
#
#
# -- 499 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2988.064516129032, najbolji fitnes 3030.0
#
#
# -- 500 --
# n = 15 broj objekata, dimenzije hromozoma
# m = 10 broj dimenzija
# rjesenje = 4015
#
# Prosjek fitnesa 2956.1290322580644, najbolji fitnes 3280.0
#
#
# Max 3835.0
